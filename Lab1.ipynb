# %% [markdown]
# <a href="https://colab.research.google.com/github/Wu2314/ie332-fall2026/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IE 332 — Lab 1: Colab Onboarding
#
# **Week 2 — your lab section's setup session, Dudley Hall 3447. Due Sunday, Sep 6, 11:59pm (Gradescope).**
#
# Welcome to your first lab! By the end of this session you'll have:
#
# - A working Google Colab environment
# - A personal copy of this notebook in Google Drive
# - A private GitHub repo for your IE 332 work
# - Your first Python cells run
# - A GitHub backup attempted or completed
# - Your first lab submitted to Gradescope
#
# **Before you begin:** download `Lab1.ipynb` from the Week 2 Lab 1 module in Brightspace. Go to https://colab.research.google.com, choose **Upload notebook**, and select the file you downloaded. Once it opens, begin with Section 1 below.
#
# Work through this notebook section by section. Each section has instructions in Markdown cells (like this one) and code cells you'll fill in or run.
#
# **If you get stuck:** raise your hand. The TAs are in the room to help you. We'd rather answer 100 questions than have you stuck.
#
# **Time budget (approximate):**
# - Sections 1–2 (Drive copy + Colab basics): 10 min
# - Section 3 (GitHub setup): 15 min
# - Section 4 (Python check): 10 min
# - Section 5 (pandas preview): 5 min
# - Sections 6–7 (GitHub backup + submit): 10 min
#
# **Only the Gradescope submission determines Lab 1 credit.** GitHub is a recommended backup; it does not block submission if authorization is delayed.
#
# ---

# %% [markdown]
# ## Section 1 — Save this notebook to YOUR Google Drive
#
# **Do this before editing or running any code.** The file you uploaded from Brightspace is open in Colab, but it is not yet stored as your personal Drive copy.
#
# **TODO:** choose **File → Save a copy in Drive**. You can also use the **Copy to Drive** button if Colab displays it.
#
# Colab opens your personal copy in a new browser tab. Its title will usually begin with `Copy of`. **Switch to that new tab before continuing.** Colab then autosaves your changes to Google Drive.
#
# ### Three ways notebooks can persist — quick reference
#
# | Mechanism | What it saves | When you use it |
# |-----------|---------------|-----------------|
# | **Save a copy in Drive** | Your working notebook in Drive | Once per notebook, before you start editing |
# | **Save a copy in GitHub** | A version-controlled backup | When you finish a lab, when GitHub authorization is available |
# | **Download .ipynb** | A local copy for Gradescope | When submitting the lab |
#
# You will attempt all three today. The downloaded `.ipynb` uploaded to Gradescope is the official submission.
#
# ---

# %% [markdown]
# ## Section 2 — Make sure Colab is working
#
# You should now be working in the Drive copy you created in Section 1. Google Colab is a hosted Python notebook environment that runs in your browser; no installation is needed.
#
# Two kinds of cells:
# - **Markdown cells** like this one contain explanations, instructions, and formatting.
# - **Code cells** like the one below contain Python you can run.
#
# To run a code cell, click it and press `Shift+Enter`, or click the ▶ button on the left.
#
# **TODO:** fill in your name in the cell below, then run it.

# %%
# TODO: put your name in the quotes below
your_name = "YOUR NAME HERE"

# Don't change this line:
print(f"Hello, {your_name}. Welcome to IE 332.")

# %% [markdown]
# ## Section 3 — GitHub for IE 332
#
# You'll keep your personal lab work in a **private GitHub repository**. Group assignments will use a separate private team repository when they are introduced. This gives you a version-controlled backup and reinforces an industry-standard workflow. Gradescope remains the official submission channel. GitHub is recommended, but it is not a grading gate for Lab 1.
#
# ### Step 3a: Sign in to GitHub
#
# Go to https://github.com/. Sign in to an existing account or create a regular free account. A GitHub Education account is optional and is not needed for this course.
#
# ### Step 3b: Create your private course repo
#
# 1. On GitHub, choose **New repository**.
# 2. Keep the owner as your personal account.
# 3. Name the repository `ie332-fall2026`.
# 4. Select **Private**.
# 5. Turn on **Add a README file** so the repository has an initial commit.
# 6. Click **Create repository**.
#
# You create and own this repository yourself; there is no GitHub Classroom invitation.
#
# ### Step 3c: Note your repo URL
#
# Once GitHub creates your repo, the URL appears in your browser. It looks like:
#
# ```
# https://github.com/YOUR-USERNAME/ie332-fall2026
# ```
#
# **TODO:** paste your repo URL in the cell below.

# %%
# TODO: paste your GitHub repo URL between the quotes
your_repo_url = "https://github.com/YOUR-USERNAME/ie332-fall2026"

print(f"Your repo: {your_repo_url}")

# %% [markdown]
# **If you hit issues:**
# - Make sure you have verified the email address on your GitHub account.
# - Make sure the repository is **Private** and has a README. Ask a TA if you cannot create it or cannot find its URL.
# - GitHub is the backup step; Gradescope is the graded submission. If GitHub authorization is delayed, finish Section 7 before the deadline and return to the backup step afterward.
#
# ---

# %% [markdown]
# ## Section 4 — Run your first Python code
#
# A quick check that Python is working. Your prerequisite covered these programming ideas, although the Python syntax may be new if your prior course used C or Java. This is just to make sure the environment is set up.
#
# Run each cell in order.

# %%
# Variables and arithmetic
a = 7
b = 3
print(f"{a} + {b} = {a + b}")
print(f"{a} * {b} = {a * b}")

# %%
# A list, a dictionary
favorite_courses = ["IE 332", "IE 330", "IE 335"]
print(favorite_courses)

course_info = {"name": "IE 332", "credits": 3, "term": "Fall 2026"}
print(course_info["name"])

# %%
# Import the libraries we'll use all semester
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print(f"pandas version: {pd.__version__}")
print(f"numpy version:  {np.__version__}")

# %% [markdown]
# If all three cells ran without errors, your Python environment is good to go. 🎉
#
# If something errored, ask a TA — there's usually a quick fix.
#
# ---

# %% [markdown]
# ## Section 5 — A tiny preview of pandas
#
# We'll learn pandas properly in **Week 4**, but here's a 30-second preview of what it does.
#
# A **DataFrame** is like a spreadsheet inside Python — rows, columns, you can filter, group, and plot.

# %%
import pandas as pd

# Build a tiny DataFrame
df = pd.DataFrame({
    "song": ["Mr. Brightside", "Pink + White", "Motion Sickness"],
    "artist": ["The Killers", "Frank Ocean", "Phoebe Bridgers"],
    "duration_s": [223, 203, 243]
})

df

# %%
# Total minutes of listening
total_minutes = df["duration_s"].sum() / 60
print(f"Total: {total_minutes:.1f} minutes")

# %% [markdown]
# That's it for pandas today. Lab 2 next week will be SQL on a real dataset.
#
# ---

# %% [markdown]
# ## Section 6 — Attempt a GitHub backup
#
# GitHub is a recommended backup, not the official Lab 1 submission. Try saving this notebook to your private course repo:
#
# 1. Click **File → Save a copy in GitHub** (top-left menu of Colab).
# 2. A dialog may ask you to authorize Colab to access GitHub. Complete the authorization.
# 3. Choose your IE 332 repo from the **Repository** dropdown.
# 4. Set the **File path** to: `labs/lab1_colab_onboarding.ipynb`
# 5. Set the **Commit message** to: `Lab 1 first commit`
# 6. Click **OK**.
#
# Verify it worked by visiting your repo on https://github.com. You should see the notebook in the `labs/` folder.
#
# If the repository is missing or authorization does not finish after a TA helps you, continue to Section 7 and submit to Gradescope. Return to the GitHub backup later.

# %% [markdown]
# ## Important details and common questions
#
# - **Drive, GitHub, and Gradescope do different jobs.** Drive is your working copy, GitHub is an optional version-controlled backup, and the downloaded notebook uploaded to Gradescope is the official submission.
# - **Colab state is temporary.** Variables and uploaded files disappear when the runtime resets. A notebook is ready only when `Runtime -> Restart session and run all` succeeds from the top.
# - **Do not place passwords, tokens, or private data in a notebook or repository.** A private repository reduces visibility; it is not a substitute for handling secrets correctly.
# - **Execution order matters.** A later cell can use a name only after the earlier cell defining it has run in the current runtime.

# %% [markdown]
# ## Section 7 — Submit to Gradescope
#
# Final step — submit your notebook to Gradescope for credit.
#
# 1. Click **File → Download → Download .ipynb** (top-left menu of Colab).
# 2. In Brightspace, open **Content → Week 2 — Lab 1: Colab Onboarding → Lab 1 submission (Gradescope)**.
# 3. Upload the `.ipynb` file you just downloaded. Do not upload the `.py` version.
# 4. Verify that Gradescope shows the correct filename and a successful submission confirmation or preview.
#
# **Lab 1 is due Sunday, Sep 6, 11:59pm** on Gradescope. A genuine attempt submitted by the deadline earns full lab credit; an empty or obviously incomplete notebook does not.
#
# Use lab time to understand the workflow and ask questions. The assignments and practicum will test correctness later.

# %% [markdown]
# ## 🎉 You're done!
#
# By submitting this notebook, you've:
#
# - ✅ Saved a personal working copy in Google Drive
# - ✅ Verified Colab works for you
# - ✅ Run your first Python cells in a Colab notebook
# - ✅ Set up or attempted the private GitHub backup workflow
# - ✅ Submitted your first lab to Gradescope
#
# **This week's lectures continue SQL with JOINs, GROUP BY, and subqueries/CTEs. Next week's lab uses SQL on the Boilermaker Brews database.**
#
# Here's a preview:
#
# ```python
# %load_ext sql
# %sql sqlite:///boilermaker_brews.db
#
# %%sql
# SELECT store_id, COUNT(*) AS n_orders
# FROM   orders
# GROUP  BY store_id
# ORDER  BY n_orders DESC
# LIMIT  5;
# ```
#
# — Prof. Miaolan Xie
